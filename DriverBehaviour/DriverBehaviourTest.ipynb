# %%
include("DriverBehaviour.jl")
using .DriverBehaviour
using Plots, Colors

#initial parameters - Simple Driver Behavior parameters
averageReactionTimeDriver = 0.75
tendancyChangeLanesDriver = 0.5
tendancyAllowChangeLanesDriver = 0.5
averageCarLengthDriver = 4.5

#Road Property parameters
numberLanesRoad = 3
speedLimitRoad = 20
lengthRoad = 1000
# Out:
# WARNING: replacing module DriverBehaviour.
# 1000

# %%
roadMatrix = DriverBehaviour.initializeRoad(numberLanesRoad, 0.5, averageCarLengthDriver, lengthRoad, 10)
heatmap(roadMatrix, legend = false, title = "Driver Distribution for Starting Density 0.5", background = :black, c = :heat)

# %%
roadMatrix = DriverBehaviour.initializeRoad(numberLanesRoad, 0.1, averageCarLengthDriver, lengthRoad, 10)
heatmap(roadMatrix, legend = false, title = "Driver Distribution for Starting Density 0.1", background = :black, c = :heat)

# %%
roadMatrix = DriverBehaviour.initializeRoad(numberLanesRoad, 0.0, averageCarLengthDriver, lengthRoad, 10)
heatmap(roadMatrix, legend = false, title = "Driver Distribution for Starting Density 0", background = :black, c = :heat)

# %%
roadMatrix = DriverBehaviour.initializeRoad(numberLanesRoad, 1.0, averageCarLengthDriver, lengthRoad, 10)
heatmap(roadMatrix, legend = false, title = "Driver Distribution for Starting Density 1", background = :black, c = :heat)
